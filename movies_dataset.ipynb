# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutuja2610647/Python_Project/blob/main/movies_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📍 Step 1: Import Libraries & Load Dataset

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4d1a1f0b-d57a-4349-94ae-09a9b2e3005b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d1a1f0b-d57a-4349-94ae-09a9b2e3005b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("movies_dataset.csv")
df.head()
# Out:
#              title                     genre  \
# 0       The Matrix            Action, Sci-Fi
# 1        Inception            Action, Sci-Fi
# 2     Interstellar  Adventure, Drama, Sci-Fi
# 3     The Prestige    Drama, Mystery, Sci-Fi
# 4  The Dark Knight      Action, Crime, Drama
#
#                                          description           director  \
# 0  A computer hacker learns about the true nature...     Lana Wachowski
# 1  A thief who steals corporate secrets through d...  Christopher Nolan
# 2  A team of explorers travel through a wormhole ...  Christopher Nolan
# 3  Two stage magicians engage in a competitive ri...  Christopher Nolan
# 4  Batman faces the Joker, a criminal mastermind ...  Christopher Nolan
#
#                                       cast
# 0         Keanu Reeves, Laurence Fishburne
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt
# 2       Matthew McConaughey, Anne Hathaway
# 3             Christian Bale, Hugh Jackman
# ...

# %% [markdown]
# 📍 Step 2: Combine All Text Columns into One

# %%
# Fill any missing values with blank
df = df.fillna('')

# Combine text data into one column for similarity
df['combined'] = df['genre'] + ' ' + df['description'] + ' ' + df['director'] + ' ' + df['cast']

# %% [markdown]
# 📍 Step 3: Create TF-IDF Matrix

# %%
# Convert text to vectors using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['combined'])

# %% [markdown]
# 📍 Step 4: Compute Cosine Similarity

# %%
# Compute similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# 📍 Step 5: Function to Recommend Similar Movies

# %%
# Movie title to index mapping
indices = pd.Series(df.index, index=df['title'])

def recommend(movie_title, num_recommendations=5):
    idx = indices[movie_title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:num_recommendations+1]
    movie_indices = [i[0] for i in sim_scores]
    return df['title'].iloc[movie_indices]

# %% [markdown]
# 📍 Step 6: Test the Recommender

# %%
recommend("Inception")
# Out:
# 6     Shutter Island
# 3       The Prestige
# 2       Interstellar
# 4    The Dark Knight
# 0         The Matrix
# Name: title, dtype: object
